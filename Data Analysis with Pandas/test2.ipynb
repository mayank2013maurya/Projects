# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'DoneDutySummaryRpt.xls',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'test1.ipynb',
#  'Untitled Folder',
#  'Untitled.ipynb']

# %%
import pandas

# %%
df1 = pandas.read_csv("supermarkets.csv")
df1.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df1.shape
# Out:
# (6, 7)

# %%
df2 = pandas.read_json("supermarkets.json")
df2.set_index("ID")
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df3 = pandas.read_excel("supermarkets.xlsx", sheetname= 0)
df3.set_index("ID")
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df4 = pandas.read_csv("supermarkets-commas.txt")
df4.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5 = pandas.read_csv("supermarkets-semi-colons.txt", sep=";")
df5.set_index("ID")
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df2.set_index("Address")
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df2 = df2.set_index("Address")

# %%
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df2.set_index()?
# Out:
#   File "<ipython-input-35-b1311c9c552c>", line 1
#     df2.set_index()?
#                    ^
# SyntaxError: invalid syntax

# %%
df2.set_index?

# %%
df2.loc["735 Dolores St":"1056 Sanchez St","Country"]
# Out:
# Address
# 735 Dolores St     USA
# 332 Hill St        USA
# 3995 23rd St       USA
# 1056 Sanchez St    USA
# Name: Country, dtype: object

# %%
df2.loc[:,"Country"]
# Out:
# Address
# 3666 21st St       USA
# 735 Dolores St     USA
# 332 Hill St        USA
# 3995 23rd St       USA
# 1056 Sanchez St    USA
# 551 Alvarado St    USA
# Name: Country, dtype: object

# %%
list(df2.loc[:,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df2.iloc[1:3,1:3]
# Out:
#                Country  Employees
# Address
# 735 Dolores St     USA         15
# 332 Hill St        USA         25

# %%
df2.iloc[1:4,1:4]
# Out:
#                Country  Employees  ID
# Address
# 735 Dolores St     USA         15   2
# 332 Hill St        USA         25   3
# 3995 23rd St       USA         10   4

# %%
df2.iloc[:,1:4]
# Out:
#                 Country  Employees  ID
# Address
# 3666 21st St        USA          8   1
# 735 Dolores St      USA         15   2
# 332 Hill St         USA         25   3
# 3995 23rd St        USA         10   4
# 1056 Sanchez St     USA         12   5
# 551 Alvarado St     USA         20   6

# %%
df2.iloc[3,1:4]
# Out:
# Country      USA
# Employees     10
# ID             4
# Name: 3995 23rd St, dtype: object

# %%
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df2.ix[1:4, "Name": "State"]
# Out:
# c:\users\mayan\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#                        Name             State
# Address
# 735 Dolores St  Bready Shop          CA 94119
# 332 Hill St     Super River  California 94114
# 3995 23rd St     Ben's Shop          CA 94114

# %%
df2.ix[1:4, "Name"]
# Out:
# c:\users\mayan\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Address
# 735 Dolores St    Bready Shop
# 332 Hill St       Super River
# 3995 23rd St       Ben's Shop
# Name: Name, dtype: object

# %%
df2.drop("City", 1)
# Out:
#                 Country  Employees  ID         Name             State
# Address
# 3666 21st St        USA          8   1      Madeira          CA 94114
# 735 Dolores St      USA         15   2  Bready Shop          CA 94119
# 332 Hill St         USA         25   3  Super River  California 94114
# 3995 23rd St        USA         10   4   Ben's Shop          CA 94114
# 1056 Sanchez St     USA         12   5      Sanchez        California
# 551 Alvarado St     USA         20   6   Richvalley          CA 94114

# %%
df2.drop("332 Hill St")
# Out:
#                           City Country  Employees  ID         Name       State
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira    CA 94114
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop    CA 94119
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop    CA 94114
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez  California
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley    CA 94114

# %%
df2.drop(df2.index[0:3], 0)
# Out:
#                           City Country  Employees  ID        Name       State
# Address
# 3995 23rd St     San Francisco     USA         10   4  Ben's Shop    CA 94114
# 1056 Sanchez St  San Francisco     USA         12   5     Sanchez  California
# 551 Alvarado St  San Francisco     USA         20   6  Richvalley    CA 94114

# %%
df2.drop(df2.index[0:3], 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-81d1c20be1c8> in <module>
# ----> 1 df2.drop(df2.index[0:3], 1)
#
# c:\users\mayan\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# c:\users\mayan\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
df2.drop(df2.columns[0:3], 1)
# Out:
#                  ID         Name             State
# Address
# 3666 21st St      1      Madeira          CA 94114
# 735 Dolores St    2  Bready Shop          CA 94119
# 332 Hill St       3  Super River  California 94114
# 3995 23rd St      4   Ben's Shop          CA 94114
# 1056 Sanchez St   5      Sanchez        California
# 551 Alvarado St   6   Richvalley          CA 94114

# %%
df2.index
# Out:
# Index(['3666 21st St', '735 Dolores St', '332 Hill St', '3995 23rd St',
#        '1056 Sanchez St', '551 Alvarado St'],
#       dtype='object', name='Address')

# %%
df2.columns
# Out:
# Index(['City', 'Country', 'Employees', 'ID', 'Name', 'State'], dtype='object')

# %%
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df2["Continent"] = ["North America"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-c5fb57f5c2ec> in <module>
# ----> 1 df2["Continent"] = ["North America"]
#
# c:\users\mayan\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# c:\users\mayan\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3192
#    3193         self._ensure_valid_index(value)
# -> 3194         value = self._sanitize_column(key, value)
#    3195         NDFrame._set_item(self, key, value)
#    3196
#
# ...

# %%
len(df2.index)
# Out:
# 6

# %%
df2.shape
# Out:
# (6, 6)

# %%
df2.shape[0]*["Mayank"]
# Out:
# ['Mayank', 'Mayank', 'Mayank', 'Mayank', 'Mayank', 'Mayank']

# %%
df2["Continent"] = df2.shape[0] * ["North America"]
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State      Continent
# Address
# 3666 21st St             CA 94114  North America
# 735 Dolores St           CA 94119  North America
# 332 Hill St      California 94114  North America
# 3995 23rd St             CA 94114  North America
# 1056 Sanchez St        California  North America
# 551 Alvarado St          CA 94114  North America

# %%
df2["Continent"] = df2["Country"] + ","+"North America"
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State          Continent
# Address
# 3666 21st St             CA 94114  USA,North America
# 735 Dolores St           CA 94119  USA,North America
# 332 Hill St      California 94114  USA,North America
# 3995 23rd St             CA 94114  USA,North America
# 1056 Sanchez St        California  USA,North America
# 551 Alvarado St          CA 94114  USA,North America

# %%
df2_t = df2.T
df2_t
# Out:
# Address         3666 21st St     735 Dolores St        332 Hill St  \
# City           San Francisco      San Francisco      San Francisco
# Country                  USA                USA                USA
# Employees                  8                 15                 25
# ID                         1                  2                  3
# Name                 Madeira        Bready Shop        Super River
# State               CA 94114           CA 94119   California 94114
# Continent  USA,North America  USA,North America  USA,North America
#
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# City           San Francisco      San Francisco      San Francisco
# Country                  USA                USA                USA
# Employees                 10                 12                 20
# ID                         4                  5                  6
# Name              Ben's Shop            Sanchez         Richvalley
# ...

# %%
df2_t["332 Hill St"] = ["Lucknow", "India", 10, 7, "Mayank's Store", "Uttar Pradesh", "Asia"]
df2_t
# Out:
# Address         3666 21st St     735 Dolores St     332 Hill St  \
# City           San Francisco      San Francisco         Lucknow
# Country                  USA                USA           India
# Employees                  8                 15              10
# ID                         1                  2               7
# Name                 Madeira        Bready Shop  Mayank's Store
# State               CA 94114           CA 94119   Uttar Pradesh
# Continent  USA,North America  USA,North America            Asia
#
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St  \
# City           San Francisco      San Francisco      San Francisco
# Country                  USA                USA                USA
# Employees                 10                 12                 20
# ID                         4                  5                  6
# Name              Ben's Shop            Sanchez         Richvalley
# ...

# %%
df2 = df2_t.T

# %%
df2
# Out:
#                           City Country Employees ID            Name  \
# Address
# 3666 21st St     San Francisco     USA         8  1         Madeira
# 735 Dolores St   San Francisco     USA        15  2     Bready Shop
# 332 Hill St            Lucknow   India        10  7  Mayank's Store
# 3995 23rd St     San Francisco     USA        10  4      Ben's Shop
# 1056 Sanchez St  San Francisco     USA        12  5         Sanchez
# 551 Alvarado St  San Francisco     USA        20  6      Richvalley
# My address             Lucknow   India        10  7  Mayank's Store
#
#                          State          Continent
# Address
# 3666 21st St          CA 94114  USA,North America
# 735 Dolores St        CA 94119  USA,North America
# 332 Hill St      Uttar Pradesh               Asia
# 3995 23rd St          CA 94114  USA,North America
# 1056 Sanchez St     California  USA,North America
# 551 Alvarado St       CA 94114  USA,North America
# ...

# %%
import geopy

# %%
dir(geopy)
# Out:
# ['ArcGIS',
#  'AzureMaps',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'units',
#  'util']
